# %% [markdown]
# <a href="https://colab.research.google.com/github/Claudio-Ferriz/Obesity-Machine-Learning-Project/blob/main/Proyecto_Final_Ferriz_Claudio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Proyecto Data Science***

# %% [markdown]
# # Objetivos analíticos e hipótesis
#
# Por medio del modelado en Machine Learning y el Aprendizaje Supervisado se busca predecir el nivel de obesidad de las personas utilizando regresión lineal en un modelo de Machine Learning.
#
# De esta manera poder brindar automatización de procesos y mejora de tiempos de analisis y evaluación del estado de salud de los pacientes dentro de instituciones y/o servicios de salud, en relación al peso de las personas y otras variables relacionadas. Y asi generar procedimientos eficientes a nivel de las instituciones y servicios, y politicas publicas de los Estados orientadas a la mejora de la calidad de vida de las personas.
#
# El presente proyecto busca demostrar por medio de su hipotesis principal que la variable Peso se encuentra condicionada por variables como Altura, Edad, Consumo frecuente de alimentos con altas calorías, Historial familiar de sobrepeso y Frecuencia de actividad fisica.
#
#
# En la Sección Exploratory Data Analysis (EDA) puede verse en detalle las preguntas que surgen de las hipótesis y visualizaciones para ser respondida por los modelos de Machine Learning a utilizar.

# %% [markdown]
# # Contexto comercial
#
# Desde instituciones públicas y privadas, empresas vinculadas a la salud y desde gobiernos nacionales se busca encontrar, por medio del analisis de datos,los indicadores, KPIs e Insights que permitan en una etapa posterior generar automatización de procesos, mejora en los tiempos de respuesta y mayor eficiencia en la generación de respuestas ante el diagnostico, la prevención y lucha contra el sobrepeso y la obesidad.

# %% [markdown]
# # Problema comercial
#
# El continente americano presenta los indices mas elevados de sobrepeso y obesidad del mundo, teniendo el 62,5% de la población adulta mayor a los 18 años con sobrepeso y 28,6% con obesidad. Y siendo Mexico (no incluyendo a Estados Unidos) el pais con los mayores valores para la región.
# A partir de datos oficiales y de entidades a nivel regional y mundial puede observarse un crecimiento alarmante y constante de los niveles de obesidad y sobrepeso en la última década.

# %% [markdown]
# # Contexto analítico
#
# El Dataset seleccionado corresponde a la estimación de obesidad de las personas de paises como Colombia, Mexico y Peru, entre los 14 y 61 años de edad, con diversos habitos alimenticios y diversas condiciones físicas para hacer de la muestra seleccionada lo más representativa posible.
#
# Los datos fueron recogidos utilizando una plataforma web donde los usuarios de forma anonima respondian a cada pregunta de donde se obtuvo la información que fue recolectada en 2111 Registros y 17 Columnas.
#
# Las Variables que se desprenden de las Columnas son las siguientes:
#
# Gender, Age, Height, Weight, Family History with Overweight, Frequent Consumption of High Caloric Food (FAVC), Frequency of Consumption of Vegetables (FCVC), Number of Main Meals (NCP), Consumption of Food Between Meals (CAEC), Smoker or not (Smoke), Consumption of Water daily (CH20), Calories Consumption Monitoring (SCC), Physical Activity Frequency (FAF), Time Using Technology Devices (TUE), Consumption of Alcohol (CALC), Transportation Used (MTRANS) y NObeyesdad (Obesity Level).
#
#
# &nbsp;
#
#
#
# *Fuente del Dataset*
#
# https://www.kaggle.com/datasets/aravindpcoder/obesity-or-cvd-risk-classifyregressorcluster

# %% [markdown]
# # Enlace a Presentación
#
# https://drive.google.com/file/d/1DidJoEMXa1OVu6hY2_ll7-H62NXxC4z1/view?usp=sharing

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://github.com/Claudio-Ferriz/Obesity-or-CVD-Risk-Project/raw/main/ObesityDataSet.csv')
df
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2111 entries, 0 to 2110
# Data columns (total 17 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Gender                          2111 non-null   object
#  1   Age                             2111 non-null   float64
#  2   Height                          2111 non-null   float64
#  3   Weight                          2111 non-null   float64
#  4   family_history_with_overweight  2111 non-null   object
#  5   FAVC                            2111 non-null   object
#  6   FCVC                            2111 non-null   float64
#  7   NCP                             2111 non-null   float64
#  8   CAEC                            2111 non-null   object
#  9   SMOKE                           2111 non-null   object
#  10  CH2O                            2111 non-null   float64
#  11  SCC                             2111 non-null   object
# ...

# %%
df.shape
# Out:
# (2111, 17)

# %%
df.Gender.value_counts()
# Out:
# Gender
# Male      1068
# Female    1043
# Name: count, dtype: int64

# %%
df.family_history_with_overweight.value_counts()
# Out:
# family_history_with_overweight
# yes    1726
# no      385
# Name: count, dtype: int64

# %%
df.NObeyesdad.value_counts()
# Out:
# NObeyesdad
# Obesity_Type_I         351
# Obesity_Type_III       324
# Obesity_Type_II        297
# Overweight_Level_I     290
# Overweight_Level_II    290
# Normal_Weight          287
# Insufficient_Weight    272
# Name: count, dtype: int64

# %%
df.Weight.mean()
# Out:
# 86.58605812648035

# %%
df.groupby('Gender')['Weight'].mean()
# Out:
# Gender
# Female    82.302364
# Male      90.769478
# Name: Weight, dtype: float64

# %% [markdown]
# ***Variables y visualizaciones***
#
# Los usuarios finales a los que apunta el presente proyecto son los mandos medios y jerárquicos de una empresa, es decir lideres de área y gerentes respectivamente. Los cuales, por medio de la información, visualización y análisis brindado,  puedan generar acciones y tomas de decisiones de nivel táctico y estratégico direccionados a generar automatización de procesos y mejora en los tiempos de respuesta. Cuya finalidad sea la mejora en la eficiencia de los diagnosticos y la prevención del sobrepeso y la obesidad.

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
#En este gráfico se busca responder a la pregunta ¿Cúal es la distribución del Peso del total del Dataset?

fig, ax = plt.subplots(figsize=(8, 4))
ax.hist(df.Weight.values.flatten(), bins=20)
plt.xlabel('Peso')
plt.ylabel('Cantidad')
plt.title('Histograma de Peso')
# Out:
# Text(0.5, 1.0, 'Histograma de Peso')

# %%
#A traves del siguiente gráfico se busca observar a la variable categorica Historia Familiar con Sobrepeso
#discriminando por Género.
#¿Cúanto impacta la historia familiar sobre las distintas variables del Dataset?
#¿Existe una diferencia clara de este atributo en relación al Género?

plt.figure(figsize=[12,5])
sns.countplot(df, x='family_history_with_overweight', hue='Gender')
# Out:
# <Axes: xlabel='family_history_with_overweight', ylabel='count'>

# %%
#En esta serie de gráficos se busca comparar entre las distintas Clasificaciones de Peso, la distribución de la
#variable númerica Peso, discriminado por Género.
#¿Cúal es la distribución del Peso según el Nivel de Obesidad y Género?

g = sns.FacetGrid(df, col='NObeyesdad',hue='Gender')
g.map(sns.histplot,'Weight')
g.add_legend()

# %%
#En este gráfico se busca observar la distribución entre cuartiles, la mediana y los valores atípicos de las
#variables Peso y Nivel de Obesidad, discriminado por Género.
#¿Cúal es la distribución de los datos de estos atributos?¿Son sustanciales los outliers presentes en este gráfico?

plt.figure(figsize=[12,5])
plt.xticks(rotation=45)
sns.boxplot(df,x='Weight',y='NObeyesdad',hue='Gender')
# Out:
# <Axes: xlabel='Weight', ylabel='NObeyesdad'>

# %%
#A traves del siguiente gráfico se busca observar a la variable categorica Consumo Frecuente de Alimentos
#con Altas Calorás discriminado por Clasificaciones de Peso.
#¿Cúanto impacta el consumo de este tipo de alimentos sobre las distintas variables del Dataset?
#¿Existe una diferencia clara de este atributo en relación al Género?
plt.figure(figsize=[12,5])
sns.countplot(df, x='FAVC', hue='NObeyesdad')
# Out:
# <Axes: xlabel='FAVC', ylabel='count'>

# %%
#En este gráfico se busca encontrar las correlaciones entre las variables númericas de Altura y Peso,
#discriminando por Género.
#¿Qué tipo de correlación surge de estos datos?

plt.figure(figsize=[12,5])
sns.scatterplot(df,x='Height',y='Weight',hue='Gender')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
#En este gráfico se busca encontrar las correlaciones entre las variables númericas de Altura y Peso,
#discriminando por Nivel de Obesidad.
#¿Qué tipo de correlación surge de estos datos?


plt.figure(figsize=[12,5])
sns.scatterplot(df,x='Height',y='Weight',hue='NObeyesdad')
# Out:
# <Axes: xlabel='Height', ylabel='Weight'>

# %%
#En este gráfico se busca encontrar la relación entre las variables númericas de Peso y Edad,
#discriminando la Frecuencia de Actividad Física.
#¿Qué tipo de correlación surge de estos datos?¿La Edad condiciona la Frecuencia de Actividad Física?

fig, ax = plt.subplots()
mapeo_colores = ax.scatter(df['Age'], df['Weight'], c=df['FAF'])
fig.colorbar(mapeo_colores)
ax.set_title('Edad , Peso y Frecuencia de Actividad Fisica')
ax.set_xlabel('Edad')
ax.set_ylabel('Peso (Kilos)')
# Out:
# Text(0, 0.5, 'Peso (Kilos)')

# %% [markdown]
# # Feature selection, elección y cálculo de métricas para validar los modelos

# %%
#Previo a utilizar las tecnicas de reducción de dimensionalidad se procede a transformar las variables categoricas
#a variables continuas.
df1=pd.get_dummies(df,drop_first=True)

# %%
#Se selecciona las variables del dataset para los ejes x e y.
X = df1.drop("Weight", axis=1)
y = df1["Weight"]

df1
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF  \
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452
#
#            TUE  Gender_Male  family_history_with_overweight_yes  ...  \
# ...

# %%
df1.dtypes
# Out:
# Age                                   float64
# Height                                float64
# Weight                                float64
# FCVC                                  float64
# NCP                                   float64
# CH2O                                  float64
# FAF                                   float64
# TUE                                   float64
# Gender_Male                              bool
# family_history_with_overweight_yes       bool
# FAVC_yes                                 bool
# CAEC_Frequently                          bool
# CAEC_Sometimes                           bool
# CAEC_no                                  bool
# SMOKE_yes                                bool
# SCC_yes                                  bool
# CALC_Frequently                          bool
# CALC_Sometimes                           bool
# CALC_no                                  bool
# MTRANS_Bike                              bool
# ...

# %% [markdown]
# ***Modelo de Regresión Lineal***

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
#Se selecciona el modelo de Regresión Lineal para evaluar sus métricas y performance a partir de los datos
#previamente trabajados.
from sklearn.linear_model import  LinearRegression as LR

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
#Utilizamos Sequential Feature Selector para seleccionar las 9 variables más representativas.
#A su vez se genera un proceso por default de cross validation utilizando 5 folds sobre el
#modelo de regresión lineal.
from mlxtend.feature_selection import SequentialFeatureSelector as SFS

sfs = SFS(LR(),
          k_features=9)

# %%
#Se entrena al Feature Selector
sfs.fit(X_train, y_train)
# Out:
# SequentialFeatureSelector(estimator=LinearRegression(), k_features=(9, 9),
#                           scoring='r2')

# %%
#Se obtienen las 9 features más representativas
sfs.k_feature_names_
# Out:
# ('Height',
#  'FAF',
#  'CAEC_Sometimes',
#  'NObeyesdad_Normal_Weight',
#  'NObeyesdad_Obesity_Type_I',
#  'NObeyesdad_Obesity_Type_II',
#  'NObeyesdad_Obesity_Type_III',
#  'NObeyesdad_Overweight_Level_I',
#  'NObeyesdad_Overweight_Level_II')

# %%
#A partir de las features anteriores se pone a entrenar y luego testear el modelo
#de Regresión Lineal para obtener como resultado su performance.
X = df1.loc[:,['Height',
 'FAF',
 'CAEC_Sometimes',
 'NObeyesdad_Normal_Weight',
 'NObeyesdad_Obesity_Type_I',
 'NObeyesdad_Obesity_Type_II',
 'NObeyesdad_Obesity_Type_III',
 'NObeyesdad_Overweight_Level_I',
 'NObeyesdad_Overweight_Level_II']]
y = df1["Weight"]

X_train,X_test,y_train,y_test = train_test_split(X,y)

model=LR()
model.fit(X_train,y_train)
y_pred_test=model.predict(X_test)
r2_score(y_pred_test,y_test)
# Out:
# 0.9569877298026351

# %% [markdown]
# ***Modelo de Árbol de Decisiones***

# %% [markdown]
# ***Primera ronda de entrenamiento***

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#Se selecciona el modelo de Regresión Lineal para evaluar sus métricas y performance a partir de los datos
#previamente trabajados y compararlo con el modelo de Árbol de Decisiones.
from sklearn.linear_model import  LinearRegression as LR

# %%
#Se selecciona el modelo de Árbol de Decisiones para evaluar sus métricas y performance a partir de los datos
#previamente trabajados.
from sklearn.tree import DecisionTreeRegressor

# %%
lr_model=LR()
lr_model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
tree_sinpoda=DecisionTreeRegressor()
tree_sinpoda.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
tree_8niveles=DecisionTreeRegressor(max_depth=8)
tree_8niveles.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
from sklearn.metrics import r2_score

# %%
y_pred_train1=lr_model.predict(X_train)
y_pred_train2=tree_sinpoda.predict(X_train)
y_pred_train3=tree_8niveles.predict(X_train)

# %%
#Regresión Lineal
r2_score(y_pred_train1,y_train)
# Out:
# 0.961346720563548

# %%
#Sin poda
r2_score(y_pred_train2,y_train)
# Out:
# 1.0

# %%
#Poda de 8 niveles
r2_score(y_pred_train3,y_train)
# Out:
# 0.9907197131644733

# %%
#Se procede a la validación cruzada para la obtención de los resultados de los tres modelos entrenados
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(lr_model, X_train, y_train).mean()
# Out:
# 0.9611013027896727

# %%
cross_val_score(tree_sinpoda, X_train, y_train).mean()
# Out:
# 0.9773079652329697

# %%
cross_val_score(tree_8niveles, X_train, y_train).mean()
# Out:
# 0.9825611984854458

# %% [markdown]
# A partir de los tres modelos trabajados a la par vemos que el modelo de Regresión Lineal da como resultado un valor similar al primer modelo de regresion utilizado en el proyecto.
#
# En cuanto al arbol sin poda se ve el overfit al momento de la validación cruzada.
#
# Por último en el tercer modelo utilizado en este apartado puede observarse el mejor resultado obtenido utilizando 8 hiperparametros (poda del árbol).
#
# En futuras líneas se buscaran la mejor combinación de hiperparametros para obtener mejores resultados.

# %% [markdown]
# ***Segunda ronda de entrenamiento***

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#Se selecciona el modelo de Árbol de Decisiones para evaluar sus métricas y performance a partir de los datos
#previamente trabajados.
from sklearn.tree import DecisionTreeRegressor

# %%
tree_9niveles=DecisionTreeRegressor(max_depth=9)
tree_9niveles.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=9)

# %%
tree_12niveles=DecisionTreeRegressor(max_depth=12)
tree_12niveles.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=12)

# %%
tree_15niveles=DecisionTreeRegressor(max_depth=15)
tree_15niveles.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=15)

# %%
from sklearn.metrics import r2_score

# %%
y_pred_train4=tree_9niveles.predict(X_train)
y_pred_train5=tree_12niveles.predict(X_train)
y_pred_train6=tree_15niveles.predict(X_train)

# %%
#Poda de 9 niveles
r2_score(y_pred_train4,y_train)
# Out:
# 0.9939288640584264

# %%
#Poda de 12 niveles
r2_score(y_pred_train5,y_train)
# Out:
# 0.9980815439724348

# %%
#Poda de 15 niveles
r2_score(y_pred_train6,y_train)
# Out:
# 0.9996188907676702

# %%
#Se procede a la validación cruzada para la obtención de los resultados de los tres modelos entrenados
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(tree_9niveles, X_train, y_train).mean()
# Out:
# 0.9849414642636042

# %%
cross_val_score(tree_12niveles, X_train, y_train).mean()
# Out:
# 0.9828308089522123

# %%
cross_val_score(tree_15niveles, X_train, y_train).mean()
# Out:
# 0.9783522935278143

# %% [markdown]
# Desde el cuarto modelo utilizado en este apartado puede observarse el mejor resultado de todos los modelos entrenados hasta el momento. El mismo utiliza 9 hiperparametros.
#
# En cuanto al quinto modelo (12 hiperparametros) y sexto modelo (15 hiperparametros), si bien pueden observarse muy buenos resultados, los mismos progresivamente disminuyen su performance.
#
# En futuras líneas se buscaran la mejor combinación de hiperparametros para obtener mejores resultados.

# %% [markdown]
# ***PCA (Principal Component Analysis)***

# %%
#Previo a utilizar las tecnicas de reducción de dimensionalidad se procede a transformar las variables categoricas
#a variables continuas.
df2=pd.get_dummies(df,drop_first=True)

df2
# Out:
#             Age    Height      Weight  FCVC  NCP      CH2O       FAF  \
# 0     21.000000  1.620000   64.000000   2.0  3.0  2.000000  0.000000
# 1     21.000000  1.520000   56.000000   3.0  3.0  3.000000  3.000000
# 2     23.000000  1.800000   77.000000   2.0  3.0  2.000000  2.000000
# 3     27.000000  1.800000   87.000000   3.0  3.0  2.000000  2.000000
# 4     22.000000  1.780000   89.800000   2.0  1.0  2.000000  0.000000
# ...         ...       ...         ...   ...  ...       ...       ...
# 2106  20.976842  1.710730  131.408528   3.0  3.0  1.728139  1.676269
# 2107  21.982942  1.748584  133.742943   3.0  3.0  2.005130  1.341390
# 2108  22.524036  1.752206  133.689352   3.0  3.0  2.054193  1.414209
# 2109  24.361936  1.739450  133.346641   3.0  3.0  2.852339  1.139107
# 2110  23.664709  1.738836  133.472641   3.0  3.0  2.863513  1.026452
#
#            TUE  Gender_Male  family_history_with_overweight_yes  ...  \
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
std = StandardScaler()
df_std = pd.DataFrame(std.fit_transform(df2))

# %%
df_std
# Out:
#             0         1         2         3         4         5         6   \
# 0    -0.522124 -0.875589 -0.862558 -0.785019  0.404153 -0.013073 -1.188039
# 1    -0.522124 -1.947599 -1.168077  1.088342  0.404153  1.618759  2.339750
# 2    -0.206889  1.054029 -0.366090 -0.785019  0.404153 -0.013073  1.163820
# 3     0.423582  1.054029  0.015808  1.088342  0.404153 -0.013073  1.163820
# 4    -0.364507  0.839627  0.122740 -0.785019 -2.167023 -0.013073 -1.188039
# ...        ...       ...       ...       ...       ...       ...       ...
# 2106 -0.525774  0.097045  1.711763  1.088342  0.404153 -0.456705  0.783135
# 2107 -0.367195  0.502844  1.800914  1.088342  0.404153 -0.004702  0.389341
# 2108 -0.281909  0.541672  1.798868  1.088342  0.404153  0.075361  0.474971
# 2109  0.007776  0.404927  1.785780  1.088342  0.404153  1.377801  0.151471
# 2110 -0.102119  0.398344  1.790592  1.088342  0.404153  1.396035  0.018996
#
# ...

# %%
from sklearn.decomposition import PCA

# %%
pca_df = PCA(2)
x_transformado=pca_df.fit_transform(df_std)

# %%
pd.DataFrame(x_transformado)
# Out:
#              0         1
# 0     2.311239  0.301822
# 1     2.500925 -1.386260
# 2     1.393693  1.809254
# 3     1.743273  2.059284
# 4     0.564368  0.292371
# ...        ...       ...
# 2106 -2.000990 -2.424141
# 2107 -2.252638 -2.382813
# 2108 -2.275529 -2.341018
# 2109 -2.447112 -2.377271
# 2110 -2.433484 -2.416618
#
# [2111 rows x 2 columns]

# %%
pca_df.explained_variance_ratio_
# Out:
# array([0.12722035, 0.0906816 ])

# %%
pca_df.explained_variance_ratio_.sum()
# Out:
# 0.2179019562858325

# %%
pca_df.components_
# Out:
# array([[-0.14668273, -0.24417269, -0.4443703 , -0.07844601, -0.07929727,
#         -0.11324985,  0.05378145,  0.03435182, -0.1143473 , -0.30920353,
#         -0.22263618,  0.31431518, -0.35152783,  0.10795021,  0.00395528,
#          0.16987174,  0.05997373, -0.20788983,  0.18941068,  0.0166249 ,
#          0.04756693,  0.01252223,  0.09652982,  0.25833779, -0.05935453,
#         -0.22154123, -0.2285929 ,  0.06761629,  0.00671499],
#        [ 0.19676895,  0.232369  , -0.03470015, -0.26921562, -0.0331808 ,
#         -0.00449551,  0.1648109 ,  0.02805753,  0.39466338,  0.1268691 ,
#         -0.02728336, -0.07677037,  0.08422365, -0.05931328,  0.04406777,
#         -0.07260864,  0.09580677, -0.34849306,  0.32042972,  0.05204371,
#          0.03498289, -0.29289042,  0.08186534, -0.00203546,  0.17737666,
#          0.18581582, -0.42011728, -0.05916684,  0.18028235]])

# %%
df_loadings=pd.DataFrame(pca_df.components_,columns=df2.columns,index=['pc1','pc2'])

# %%
df_loadings
# Out:
#           Age    Height   Weight      FCVC       NCP      CH2O       FAF  \
# pc1 -0.146683 -0.244173 -0.44437 -0.078446 -0.079297 -0.113250  0.053781
# pc2  0.196769  0.232369 -0.03470 -0.269216 -0.033181 -0.004496  0.164811
#
#           TUE  Gender_Male  family_history_with_overweight_yes  ...  \
# pc1  0.034352    -0.114347                           -0.309204  ...
# pc2  0.028058     0.394663                            0.126869  ...
#
#      MTRANS_Bike  MTRANS_Motorbike  MTRANS_Public_Transportation  \
# pc1     0.016625          0.047567                      0.012522
# pc2     0.052044          0.034983                     -0.292890
#
#      MTRANS_Walking  NObeyesdad_Normal_Weight  NObeyesdad_Obesity_Type_I  \
# pc1        0.096530                  0.258338                  -0.059355
# pc2        0.081865                 -0.002035                   0.177377
#
#      NObeyesdad_Obesity_Type_II  NObeyesdad_Obesity_Type_III  \
# ...

# %%
def get_plot(df):
  # Get the loadings of x and y axes
  xs = df.loc['pc1']
  ys = df.loc['pc2']

  plt.figure(figsize=[12,8])
  # Plot the loadings on a scatterplot
  for i, varnames in enumerate(df.columns):

      plt.arrow(
          0, 0, # coordinates of arrow base
          xs[i], # length of the arrow along x
          ys[i], # length of the arrow along y
          color='k',
          head_width=0.01
          )
      plt.text(xs[i], ys[i], varnames)

  # Define the axes
  xticks = np.linspace(-0.8, 0.8, num=5)
  yticks = np.linspace(-0.8, 0.8, num=5)
  plt.xticks(xticks)
  plt.yticks(yticks)
  plt.xlabel('PC1')
  plt.ylabel('PC2')

  # Show plot
  plt.title('2D Loading plot with vectors')
  plt.grid('True')
  plt.show()

# %%
get_plot(df_loadings)
# Out:
# <ipython-input-79-8d04f92acded>:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   xs[i], # length of the arrow along x
# <ipython-input-79-8d04f92acded>:13: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ys[i], # length of the arrow along y
# <ipython-input-79-8d04f92acded>:17: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   plt.text(xs[i], ys[i], varnames)

# %% [markdown]
# A partir de las variables seleccionadas y la generación del PCA (Principal Component Analysis) para la reducción de la dimensionalidad, utilizando dos de los primeros componentes principales, se obtienen resultados que no son optimos en relación a los modelos ya trabajados.

# %% [markdown]
# ***Ensamble de modelos***

# %% [markdown]
# ***Bagging***

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
#Se selecciona el modelo de Árbol de Decisiones para evaluar sus métricas y performance a partir de los datos
#previamente trabajados.
from sklearn.tree import DecisionTreeRegressor

# %%
#Se selecciona un Árbol de Decisión por encima de un modelo de Regresión Lineal porque el primero
#tiende a tener varianza. Se elige un Árbol de 15 hojas porque su performance, respecto a otros modelos del
#mismo tipo, no genera el mejor resultado.
tree_15niveles=DecisionTreeRegressor(max_depth=15)
tree_15niveles.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=15)

# %%
from sklearn.metrics import r2_score

# %%
y_pred_train6=tree_15niveles.predict(X_train)

# %%
#Poda de 15 niveles
r2_score(y_pred_train6,y_train)
# Out:
# 0.9998284139738923

# %%
#Se procede a la validación cruzada para la obtención de los resultados del modelo entrenado
#para luego comparar los resultados utilizando Bagging.
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(tree_15niveles, X_train, y_train)
# Out:
# array([0.9760163 , 0.97867509, 0.98080005, 0.97636258, 0.97459254])

# %%
cross_val_score(tree_15niveles, X_train, y_train).std()
# Out:
# 0.0024910638556998876

# %%
cross_val_score(tree_15niveles, X_train, y_train).mean()
# Out:
# 0.9776977109492833

# %%
#Se importa el Bagging especifico para utilizar en los modelos de regresión.
from sklearn.ensemble import BaggingRegressor

# %%
BaggedTree1=BaggingRegressor(tree_15niveles,n_estimators=30)

# %%
#Se entrena el modelo y se observan las metricas y resultados para comparar su performance.
cross_val_score(BaggedTree1, X_train, y_train)
# Out:
# array([0.98438159, 0.98620952, 0.9863585 , 0.98634303, 0.98701314])

# %%
cross_val_score(BaggedTree1, X_train, y_train).std()
# Out:
# 0.0013852293362547825

# %%
cross_val_score(BaggedTree1, X_train, y_train).mean()
# Out:
# 0.9853346647699576

# %% [markdown]
# A partir del entrenamiento del mismo modelo (15 hiperparametros) utilizando la CrossValidation y el Bagging se observa una mejora en los resultados a partir de las mismas metricas.
#
# Si bien el modelo performaba muy bien en relación al r2 y el desvio estandar, al utilizar Bagging se generan leves mejores resultados.

# %% [markdown]
# ***Gridsearch***

# %%
df3 = df

X = df3.drop("Weight", axis=1)
y = df3["Weight"]

df3
# Out:
#       Gender        Age    Height      Weight family_history_with_overweight  \
# 0     Female  21.000000  1.620000   64.000000                            yes
# 1     Female  21.000000  1.520000   56.000000                            yes
# 2       Male  23.000000  1.800000   77.000000                            yes
# 3       Male  27.000000  1.800000   87.000000                             no
# 4       Male  22.000000  1.780000   89.800000                             no
# ...      ...        ...       ...         ...                            ...
# 2106  Female  20.976842  1.710730  131.408528                            yes
# 2107  Female  21.982942  1.748584  133.742943                            yes
# 2108  Female  22.524036  1.752206  133.689352                            yes
# 2109  Female  24.361936  1.739450  133.346641                            yes
# 2110  Female  23.664709  1.738836  133.472641                            yes
#
# ...

# %%
df3.dtypes
# Out:
# Gender                             object
# Age                               float64
# Height                            float64
# Weight                            float64
# family_history_with_overweight     object
# FAVC                               object
# FCVC                              float64
# NCP                               float64
# CAEC                               object
# SMOKE                              object
# CH2O                              float64
# SCC                                object
# FAF                               float64
# TUE                               float64
# CALC                               object
# MTRANS                             object
# NObeyesdad                         object
# dtype: object

# %%
numeric_features_list = df3.select_dtypes(include=['int64', 'float64']).drop(['Weight'], axis=1).columns
categorical_features_list = df3.select_dtypes(include=['object']).columns

# %%
numeric_features_list
# Out:
# Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')

# %%
categorical_features_list
# Out:
# Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object')

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
from sklearn.linear_model import  LinearRegression as LR

# %%
from sklearn.metrics import mean_squared_error, r2_score

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# %%
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

# %%
categorical_transformer = Pipeline(steps=[
      ('imputer', SimpleImputer(strategy='most_frequent')),
      ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# %%
from sklearn.compose import ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('numeric', numeric_transformer, numeric_features_list),
        ('categorical', categorical_transformer, categorical_features_list)])

# %%
preprocessor
# Out:
# ColumnTransformer(transformers=[('numeric',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='median')),
#                                                  ('scaler', StandardScaler())]),
#                                  Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')),
#                                 ('categorical',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('onehot',
#                                                   OneHotEncoder(handle_unknown='ignore'))]),
#                                  Index(['Gender', 'family_history_with_overweight', 'FAVC', 'CAEC', 'SMOKE',
#        'SCC', 'CALC', 'MTRANS', 'NObeyesdad'],
#       dtype='object'))])

# %%
pipe1 = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regressor', LR())])

# %%
pipe1
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %%
def check_params_step(pipeline, params_keyword):
    all_params = pipeline.get_params().keys()
    available_params = [x for x in all_params if params_keyword in x]
    if len(available_params)==0:
        return "No matching params found!"
    else:
        return available_params

# %%
check_params_step(pipe1, 'imputer')
# Out:
# ['preprocessor__numeric__imputer',
#  'preprocessor__numeric__imputer__add_indicator',
#  'preprocessor__numeric__imputer__copy',
#  'preprocessor__numeric__imputer__fill_value',
#  'preprocessor__numeric__imputer__keep_empty_features',
#  'preprocessor__numeric__imputer__missing_values',
#  'preprocessor__numeric__imputer__strategy',
#  'preprocessor__categorical__imputer',
#  'preprocessor__categorical__imputer__add_indicator',
#  'preprocessor__categorical__imputer__copy',
#  'preprocessor__categorical__imputer__fill_value',
#  'preprocessor__categorical__imputer__keep_empty_features',
#  'preprocessor__categorical__imputer__missing_values',
#  'preprocessor__categorical__imputer__strategy']

# %%
params_grid = [

        {
        'regressor': [DecisionTreeRegressor()],
        'regressor__max_leaf_nodes': [8, 10, 15],
        'preprocessor__numeric__imputer__strategy': ['mean', 'median']
         },


        {
        'regressor': [LR()],
        'preprocessor__numeric__imputer__strategy': ['mean', 'median']
         },

        {
        'regressor': [RandomForestRegressor()],
        'preprocessor__numeric__imputer__strategy': ['mean', 'median'],
        'regressor__n_estimators': [200, 300, 500],
        'regressor__max_depth': [5, 7, 9]
         }

               ]

# %%
pipe2 = Pipeline(steps=[('preprocessor', preprocessor),
                      ('regressor', LR())])

# %%
from sklearn.model_selection import GridSearchCV

GS = GridSearchCV(pipe2, params_grid)

GS.fit(X_train, y_train)
# Out:
# GridSearchCV(estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('numeric',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer(strategy='median')),
#                                                                                          ('scaler',
#                                                                                           StandardScaler())]),
#                                                                          Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')),
#                                                                         ('categorical',
#                                                                          Pipeline(steps=[('imputer',
# ...

# %%
pd.DataFrame(GS.cv_results_)
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.021921      0.003027         0.007280        0.000319
# 1        0.021995      0.001123         0.007461        0.000739
# 2        0.021937      0.000804         0.006985        0.000126
# 3        0.022537      0.001333         0.007929        0.001495
# 4        0.021408      0.000398         0.006992        0.000151
# 5        0.022971      0.001327         0.008234        0.001631
# 6        0.039997      0.015381         0.015234        0.004535
# 7        0.042105      0.015717         0.015756        0.005951
# 8        0.943193      0.028384         0.021189        0.003467
# 9        1.602190      0.264377         0.028931        0.005213
# 10       2.524003      0.289353         0.040933        0.007326
# 11       1.184543      0.016625         0.021263        0.000616
# 12       1.939310      0.250028         0.033013        0.007431
# ...

# %%
grid=pd.DataFrame(GS.cv_results_)

# %%
grid.sort_values('rank_test_score')
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 25       3.763224      0.236633         0.052014        0.004857
# 15       2.351685      0.276301         0.037071        0.006403
# 24       2.364085      0.272173         0.035680        0.005551
# 16       3.770503      0.282270         0.056921        0.008494
# 23       1.605024      0.232205         0.028186        0.005693
# 14       1.639297      0.249001         0.028885        0.006200
# 22       3.161805      0.283744         0.049581        0.008494
# 21       1.847361      0.179535         0.029039        0.000885
# 11       1.184543      0.016625         0.021263        0.000616
# 12       1.939310      0.250028         0.033013        0.007431
# 13       3.114502      0.273147         0.045079        0.007171
# 20       1.329576      0.182496         0.025365        0.003673
# 7        0.042105      0.015717         0.015756        0.005951
# ...

# %%
GS.best_estimator_
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %%
GS.best_params_
# Out:
# {'preprocessor__numeric__imputer__strategy': 'median',
#  'regressor': RandomForestRegressor(),
#  'regressor__max_depth': 9,
#  'regressor__n_estimators': 500}

# %%
final_model=GS.best_estimator_

# %%
final_model.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('numeric',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   Index(['Age', 'Height', 'FCVC', 'NCP', 'CH2O', 'FAF', 'TUE'], dtype='object')),
#                                                  ('categorical',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehot',
# ...

# %%
final_model.score(X_test,y_test)
# Out:
# 0.9875934333116537

# %% [markdown]
# # Explicabilidad del modelo seleccionado

# %% [markdown]
# ***SHAP (Shapley Additive Explanations)***

# %%
# !pip install shap

# %%
import shap

# %%
random_forest = RandomForestRegressor(500,max_depth=9)
random_forest.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=9, n_estimators=500)

# %%
random_forest.score(X_test,y_test)
# Out:
# 0.9883178536419082

# %%
prediction = random_forest.predict(X_test)
performance = r2_score(y_test, prediction)
performance
# Out:
# 0.9883178536419082

# %%
y_train.mean()
# Out:
# 86.76586963802906

# %%
X_test.shape
# Out:
# (528, 28)

# %%
explainer = shap.Explainer(random_forest)

# %%
shap_values = explainer(X_test)

# %%
# Por medio del gráfico de fuerza se pueden observar las variables mas relevantes que afectan a cada registro
# seleccionado para su analisis.

shap.initjs()
shap.plots.force(shap_values[144],figsize=(8, 3))
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# Por medio de este gráfico puede verse el valor medio de los principales feature del modelo seleccionado.

shap.plots.bar(shap_values)

# %%
# En este gráfico se ve de forma disgregada el valor medio del gráfico anterior, siendo cada punto una
# persona encuestada.

shap.plots.beeswarm(shap_values)

# %%
# A partir de este gráfico se ve localmente, para una prediccion a elección, la importancia de las principales
# features usando los valores shap.

shap.plots.waterfall(shap_values[38])

# %%
# En este gráfico de fuerza se pueden observar las variables mas relevantes que afectan a más de un registro
# a elección para luego compararlos entre ellos y realizar un analisis pertinente.

shap.initjs()
shap.force_plot(explainer.expected_value, shap_values.values[:30,:],X_test.iloc[:30,:])
# Out:
# <div align='center'><img src='data:image/png;base64,...' /></div><script charset='utf-8'>/*! For license information please see bundle.js.LICENSE.txt */
# ...

# %%
# En este gráfico se observa la interaccion entre el feature 'Height', y al no aclarar la siguiente shap_values, la variable con
# mayor varianza

shap.plots.scatter(shap_values[:,"Height"], color=shap_values)

# %%
# En este gráfico se observa la interacción entre 'Height' y 'NCP'

shap.plots.scatter(shap_values[:,"Height"], color=shap_values[:,"NCP"])

# %% [markdown]
# # Conclusiones
#
# A partir de los pasos realizados sobre el feature selection, la elección de un módelo de un modelo de Random Forest Regressor, el entrenamiento, validación cruzada y testeo del mismo, se obtuvieron los mejores resultados sobre otros modelos por medio de la comparación en Gridsearch. Si bien se utilizo Bagging sobre Decision Tree el mejor resultado surge del modelo previamente mencionado. Dando como resultado variables independientes que explican la variabilidad de la variable dependiente y que el modelo predice cercano al valor perfecto de 1.
#
# Dicho de otra manera el modelo de Random Forest Regressor posee una gran performance en relación al dataset seleccionado y permite realizar predicciones de las variables clave para el modelo de negocio.
